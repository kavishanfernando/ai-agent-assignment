# %% [markdown]
# # Exploration Notebook
#
# This notebook is intended for exploratory data analysis and experimentation with the AI agent system. It will cover various aspects of the system, including agent interactions, tool selection, and performance metrics.

# %%
# Import necessary libraries
import sys
sys.path.append('../src')

# Import the main components of the AI agent system
from agents.explorer_agent import ExplorerAgent
from agents.manager_agent import ManagerAgent
from services.inference import perform_inference
from utils.metrics import track_performance

# Initialize agents
explorer_agent = ExplorerAgent()
manager_agent = ManagerAgent()

# Example of analyzing a request
request = "What is the weather like today?"
tool = explorer_agent.analyze_request(request)
print(f"Selected tool for request: {tool}")

# Perform inference using the selected tool
response = perform_inference(tool, request)
print(f"Response from tool: {response}")

# Track performance metrics
performance = track_performance()
print(f"Performance metrics: {performance}")
